# %%
import numpy as np
import pandas as pd

import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import r2_score

# %%
print("Loading Data.......")

data = pd.read_csv('/Users/shahidiqbal/Documents/Shahid/Govt_Jobs/VSCode/GenAi/Machine Learning/concrete_data.csv')

print("Data Loaded Successfully")
# Out:
# Loading Data.......
# Data Loaded Successfully

# %%
data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  ...  Fine Aggregate  Age  Strength
# 0   540.0                 0.0      0.0  ...           676.0   28     79.99
# 1   540.0                 0.0      0.0  ...           676.0   28     61.89
# 2   332.5               142.5      0.0  ...           594.0  270     40.27
# 3   332.5               142.5      0.0  ...           594.0  365     41.05
# 4   198.6               132.4      0.0  ...           825.5  360     44.30
#
# [5 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cement              1030 non-null   float64
#  1   Blast Furnace Slag  1030 non-null   float64
#  2   Fly Ash             1030 non-null   float64
#  3   Water               1030 non-null   float64
#  4   Superplasticizer    1030 non-null   float64
#  5   Coarse Aggregate    1030 non-null   float64
#  6   Fine Aggregate      1030 non-null   float64
#  7   Age                 1030 non-null   int64
#  8   Strength            1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.6 KB

# %%
data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(25)

# %%
data.describe()
# Out:
#             Cement  Blast Furnace Slag  ...          Age     Strength
# count  1030.000000         1030.000000  ...  1030.000000  1030.000000
# mean    281.167864           73.895825  ...    45.662136    35.817961
# std     104.506364           86.279342  ...    63.169912    16.705742
# min     102.000000            0.000000  ...     1.000000     2.330000
# 25%     192.375000            0.000000  ...     7.000000    23.710000
# 50%     272.900000           22.000000  ...    28.000000    34.445000
# 75%     350.000000          142.950000  ...    56.000000    46.135000
# max     540.000000          359.400000  ...   365.000000    82.600000
#
# [8 rows x 9 columns]

# %%
X = data.drop(columns=['Strength'])
y = data.iloc[:, -1]

# %%
X
# Out:
#       Cement  Blast Furnace Slag  ...  Fine Aggregate  Age
# 0      540.0                 0.0  ...           676.0   28
# 1      540.0                 0.0  ...           676.0   28
# 2      332.5               142.5  ...           594.0  270
# 3      332.5               142.5  ...           594.0  365
# 4      198.6               132.4  ...           825.5  360
# ...      ...                 ...  ...             ...  ...
# 1025   276.4               116.0  ...           768.3   28
# 1026   322.2                 0.0  ...           813.4   28
# 1027   148.5               139.4  ...           780.0   28
# 1028   159.1               186.7  ...           788.9   28
# 1029   260.9               100.5  ...           761.5   28
#
# [1030 rows x 8 columns]

# %%
y
# Out:
# 0       79.99
# 1       61.89
# 2       40.27
# 3       41.05
# 4       44.30
#         ...
# 1025    44.28
# 1026    31.18
# 1027    23.70
# 1028    32.77
# 1029    32.40
# Name: Strength, Length: 1030, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#       Cement  Blast Furnace Slag  ...  Fine Aggregate  Age
# 107    323.7               282.8  ...           659.9    7
# 57     198.6               132.4  ...           825.5    3
# 1029   260.9               100.5  ...           761.5   28
# 884    300.0                 0.0  ...           728.0   28
# 559    239.6               359.4  ...           664.3   28
# ...      ...                 ...  ...             ...  ...
# 363    218.2                54.6  ...           792.7  100
# 440    190.3                 0.0  ...           798.9   28
# 77     425.0               106.3  ...           887.1    3
# 130    323.7               282.8  ...           659.9   28
# 542    255.0                 0.0  ...           945.0   90
#
# [824 rows x 8 columns]

# %%
X_test
# Out:
#      Cement  Blast Furnace Slag  Fly Ash  ...  Coarse Aggregate  Fine Aggregate  Age
# 903   155.0                 0.0    143.0  ...            1047.0           697.0   28
# 698   203.5               305.3      0.0  ...             963.4           630.0   28
# 588   186.2               124.1      0.0  ...            1083.4           764.3    7
# 188   222.4                 0.0     96.7  ...             967.1           870.3  100
# 94    313.3               262.2      0.0  ...            1046.9           611.8    7
# ..      ...                 ...      ...  ...               ...             ...  ...
# 986   272.8               105.1     81.8  ...             904.0           679.7   28
# 504   491.0                26.0    123.0  ...             822.0           699.0    3
# 713   157.0               236.0      0.0  ...             935.4           781.2    3
# 322   249.1                 0.0     98.8  ...             987.8           889.0   56
# 715   141.3               212.0      0.0  ...             971.8           748.5   90
#
# [206 rows x 8 columns]

# %%
for col in X_train.columns:
    plt.figure(figsize=(14,4))

    plt.subplot(1, 2, 1)
    sns.kdeplot(X_train[col])
    plt.title(col)

    plt.subplot(1, 2, 2)
    stats.probplot(X_train[col], dist='norm', plot=plt)
    plt.title(col)


plt.show()

# %% [markdown]
# ## Predicting without PowerTransformer

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.5650535139934256

# %%
print(np.mean(cross_val_score(lr, X, y, scoring='r2')))
# Out:
# 0.4609940491662866

# %% [markdown]
# ## Predicting using Box-Cox

# %%
## The default method of PowerTransformer is 'yeo-johnson'
pt =  PowerTransformer(method='box-cox')

# %%
X_train_transformed = pt.fit_transform(X_train+00000.1)
X_test_transformed = pt.transform(X_test+00000.1)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train_transformed, y_train)
# Out:
# LinearRegression()

# %%
pd.DataFrame({'col': X_train.columns, 'Box-Cox Lambda': pt.lambdas_})
# Out:
#                   col  Box-Cox Lambda
# 0              Cement        0.211912
# 1  Blast Furnace Slag        0.030775
# 2             Fly Ash       -0.092941
# 3               Water        0.631453
# 4    Superplasticizer        0.239242
# 5    Coarse Aggregate        1.060517
# 6      Fine Aggregate        1.789111
# 7                 Age        0.031199

# %%
y_pred = lr.predict(X_test_transformed)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.787149320087102

# %%
# Validating with cross val score
pt = PowerTransformer(method='box-cox')
X_transformed = pt.fit_transform(X+00000.1)

lr = LinearRegression()

print('LR CVS is ', np.mean(cross_val_score(lr, X_transformed, y, scoring='r2')))
# Out:
# LR CVS is  0.6737297873391774

# %%
X_train_transformed = pd.DataFrame(X_train_transformed, columns=X_train.columns)


for col in X_train_transformed.columns:
    plt.figure(figsize=(15,5))
    
    plt.subplot(1,2,1)
    sns.kdeplot(X_train[col])
    plt.title(col)

    plt.subplot(1,2,2)
    sns.kdeplot(X_train_transformed[col])
    plt.title(col)

plt.show()

# %% [markdown]
# ## Predicting using yeo-johnson

# %%
## The default method of PowerTransformer is 'yeo-johnson'

pt1 = PowerTransformer()

# %%
X_train_transformed1 = pt1.fit_transform(X_train)
X_test_transformed1 = pt1.transform(X_test)

# %%
pd.DataFrame({'col': X_train.columns, 'yeo-johnson': pt1.lambdas_})
# Out:
#                   col  yeo-johnson
# 0              Cement     0.209613
# 1  Blast Furnace Slag     0.006277
# 2             Fly Ash    -0.143241
# 3               Water     0.629582
# 4    Superplasticizer     0.243301
# 5    Coarse Aggregate     1.060653
# 6      Fine Aggregate     1.790102
# 7                 Age    -0.012265

# %%
lr1 = LinearRegression()

lr1.fit(X_train_transformed1, y_train)
y_pred = lr1.predict(X_test_transformed1)

r2_score(y_test, y_pred)
# Out:
# 0.7907112927195985

# %%
# Validating with cross val score
pt = PowerTransformer()
X_transformed = pt.fit_transform(X)

lr = LinearRegression()

print('LR CVS is ', np.mean(cross_val_score(lr, X_transformed, y, scoring='r2')))
# Out:
# LR CVS is  0.6834625130236816

# %%
pd.DataFrame({'col': X_train.columns, 'Box-Cox lambda': pt.lambdas_, 'yeo-johnson lambda': pt1.lambdas_})
# Out:
#                   col  Box-Cox lambda  yeo-johnson lambda
# 0              Cement        0.169544            0.209613
# 1  Blast Furnace Slag        0.016633            0.006277
# 2             Fly Ash       -0.136480           -0.143241
# 3               Water        0.808438            0.629582
# 4    Superplasticizer        0.264160            0.243301
# 5    Coarse Aggregate        1.129395            1.060653
# 6      Fine Aggregate        1.830764            1.790102
# 7                 Age        0.001771           -0.012265

# %%
X_train_transformed1=pd.DataFrame(X_train_transformed1, columns=X_train.columns)

for col in X_train_transformed1.columns:
    plt.figure(figsize=(15,5))
    
    plt.subplot(1,2,1)
    sns.kdeplot(X_train[col])
    plt.title(col)

    plt.subplot(1,2,2)
    sns.kdeplot(X_train_transformed1[col])
    plt.title(col)

plt.show()

# %%
for col in X_train_transformed1.columns:
    plt.figure(figsize=(15,5))
    
    plt.subplot(1,2,1)
    stats.probplot(X_train[col], dist='norm', plot=plt)
    plt.title(col)

    plt.subplot(1,2,2)
    stats.probplot(X_train_transformed1[col], dist='norm', plot=plt)
    plt.title(col)

plt.show()
