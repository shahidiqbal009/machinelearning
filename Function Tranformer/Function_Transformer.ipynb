# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
print("Loadind Data......")

df = pd.read_csv('/Users/shahidiqbal/Documents/Shahid/Govt_Jobs/VSCode/GenAi/ML/train.csv', usecols=['Age', 'Fare', 'Survived'])

print('Data Loaded Successfully')
# Out:
# Loadind Data......
# Data Loaded Successfully

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Age       714 non-null    float64
#  2   Fare      891 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 21.0 KB

# %%
df.isnull().sum()
# Out:
# Survived      0
# Age         177
# Fare          0
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df.isnull().sum()
# Out:
# Survived    0
# Age         0
# Fare        0
# dtype: int64

# %%
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
X = df.iloc[:,1:3]
y = df.iloc[:,0]

# %%
X
# Out:
#            Age     Fare
# 0    22.000000   7.2500
# 1    38.000000  71.2833
# 2    26.000000   7.9250
# 3    35.000000  53.1000
# 4    35.000000   8.0500
# ..         ...      ...
# 886  27.000000  13.0000
# 887  19.000000  30.0000
# 888  29.699118  23.4500
# 889  26.000000  30.0000
# 890  32.000000   7.7500
#
# [891 rows x 2 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#            Age      Fare
# 269  35.000000  135.6333
# 567  29.000000   21.0750
# 38   18.000000   18.0000
# 305   0.920000  151.5500
# 380  42.000000  227.5250
# ..         ...       ...
# 227  20.500000    7.2500
# 531  29.699118    7.2292
# 344  36.000000   13.0000
# 695  52.000000   13.5000
# 370  25.000000   55.4417
#
# [712 rows x 2 columns]

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
sns.kdeplot(X_train['Age'])
plt.title('Age PDF')

plt.subplot(1, 2, 2)
stats.probplot(X_train['Age'], dist = 'norm', plot=plt)
plt.title('Age QQ Plot')

plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
sns.kdeplot(X_train['Fare'])
plt.title('Fare PDF')


plt.subplot(1, 2, 2)
stats.probplot(X_train['Fare'], dist='norm', plot=plt)
plt.title('Fare QQ Plot')


plt.show()

# %% [markdown]
# ## Training without applying Function Transformer

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
lr1 = LogisticRegression()

# %%
lr1.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = lr1.predict(X_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.6536312849162011

# %% [markdown]
# ## Training Using Function Tranformer on Both Columns

# %%
from sklearn.preprocessing import FunctionTransformer

# %%
ft = FunctionTransformer(func=np.log1p)

# %%
X_train_transformed = ft.fit_transform(X_train)
X_test_transformed = ft.transform(X_test)

# %%
lr2 = LogisticRegression()

# %%
lr2.fit(X_train_transformed, y_train)
# Out:
# LogisticRegression()

# %%
y_pred2 = lr2.predict(X_test_transformed)

# %%
accuracy_score(y_test, y_pred2)
# Out:
# 0.6927374301675978

# %%
plt.figure(figsize=(15,5))

plt.subplot(2, 2, 1)
stats.probplot(X_train['Age'], dist='norm', plot=plt)
plt.title('Age Before Log')


plt.subplot(2, 2, 2)
stats.probplot(X_train_transformed['Age'], dist='norm', plot=plt)
plt.title('Age After Log')


plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
stats.probplot(X_train['Fare'], dist='norm', plot=plt)
plt.title('Fare Before Log')


plt.subplot(1, 2, 2)
stats.probplot(X_train_transformed['Fare'], dist='norm', plot=plt)
plt.title('Fare After Log')

plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
sns.kdeplot(X_train['Age'])
plt.title('Age After Log')

plt.subplot(1, 2, 2)
sns.kdeplot(X_train_transformed['Age'])
plt.title('Age After Log')

plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
sns.kdeplot(X_train['Fare'])
plt.title('Fare Before Log')

plt.subplot(1, 2, 2)
sns.kdeplot(X_train_transformed['Fare'])
plt.title('Fare After Log')

plt.show()

# %% [markdown]
# ## Training Using Function Tranformer on Single Column

# %%
Fare_train_Column = X_train['Fare']
Fare_test_Column = X_test['Fare']

# %%
ft = FunctionTransformer(func=np.log1p)

# %%
X_train['Fare'] = ft.fit_transform(Fare_train_Column)

# %%
X_train
# Out:
#            Age      Fare
# 269  35.000000  4.917301
# 567  29.000000  3.094446
# 38   18.000000  2.944439
# 305   0.920000  5.027492
# 380  42.000000  5.431646
# ..         ...       ...
# 227  20.500000  2.110213
# 531  29.699118  2.107689
# 344  36.000000  2.639057
# 695  52.000000  2.674149
# 370  25.000000  4.033208
#
# [712 rows x 2 columns]

# %%
X_test['Fare'] = ft.transform(Fare_test_Column)

# %%
X_test
# Out:
#       Age      Fare
# 741  36.0  4.380150
# 681  27.0  4.353231
# 432  42.0  3.295837
# 44   19.0  2.183711
# 348   3.0  2.827314
# ..    ...       ...
# 390  36.0  4.795791
# 1    38.0  4.280593
# 191  19.0  2.639057
# 396  31.0  2.180892
# 226  19.0  2.442347
#
# [179 rows x 2 columns]

# %%
plt.figure(figsize=(15,5))


sns.kdeplot(X_train['Fare'])
plt.title('Fare Afetr Log')

plt.show()

# %%
plt.figure(figsize=(15,5))


sns.kdeplot(X_train['Age'])
plt.title('Age After Log')



plt.show()

# %%
lr3 = LogisticRegression()

# %%
lr3.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr3.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.6368715083798883
