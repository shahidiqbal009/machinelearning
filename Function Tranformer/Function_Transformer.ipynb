# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
print("Loadind Data......")

df = pd.read_csv('/Users/shahidiqbal/Documents/Shahid/Govt_Jobs/VSCode/GenAi/ML/train.csv', usecols=['Age', 'Fare', 'Survived'])

print('Data Loaded Successfully')
# Out:
# Loadind Data......
# Data Loaded Successfully

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Age       714 non-null    float64
#  2   Fare      891 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 21.0 KB

# %%
df.isnull().sum()
# Out:
# Survived      0
# Age         177
# Fare          0
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df.isnull().sum()
# Out:
# Survived    0
# Age         0
# Fare        0
# dtype: int64

# %%
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
X = df.iloc[:,1:3]
y = df.iloc[:,0]

# %%
X
# Out:
#            Age     Fare
# 0    22.000000   7.2500
# 1    38.000000  71.2833
# 2    26.000000   7.9250
# 3    35.000000  53.1000
# 4    35.000000   8.0500
# ..         ...      ...
# 886  27.000000  13.0000
# 887  19.000000  30.0000
# 888  29.699118  23.4500
# 889  26.000000  30.0000
# 890  32.000000   7.7500
#
# [891 rows x 2 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape
# Out:
# (712, 2)

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
sns.kdeplot(X_train['Age'])
plt.title('Age PDF')

plt.subplot(1, 2, 2)
stats.probplot(X_train['Age'], dist = 'norm', plot=plt)
plt.title('Age QQ Plot')

plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
sns.kdeplot(X_train['Fare'])
plt.title('Fare PDF')


plt.subplot(1, 2, 2)
stats.probplot(X_train['Fare'], dist='norm', plot=plt)
plt.title('Fare QQ Plot')


plt.show()

# %% [markdown]
# ## Training without applying Function Transformer

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6703910614525139

# %% [markdown]
# ## Training Using Function Tranformer

# %%
from sklearn.preprocessing import FunctionTransformer

# %%
ft = FunctionTransformer(func=np.log1p)

# %%
X_train_tranformed = ft.fit_transform(X_train)
X_test_transformed = ft.transform(X_test)

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train_tranformed, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test_transformed)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.6815642458100558

# %%
plt.figure(figsize=(15,5))

plt.subplot(2, 2, 1)
stats.probplot(X_train['Age'], dist='norm', plot=plt)
plt.title('Age Before Log')


plt.subplot(2, 2, 2)
stats.probplot(X_train_tranformed['Age'], dist='norm', plot=plt)
plt.title('Age After Log')


plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
stats.probplot(X_train['Fare'], dist='norm', plot=plt)
plt.title('Fare Before Log')


plt.subplot(1, 2, 2)
stats.probplot(X_train_tranformed['Fare'], dist='norm', plot=plt)
plt.title('Fare After Log')

plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
sns.kdeplot(X_train['Age'])
plt.title('Age After Log')

plt.subplot(1, 2, 2)
sns.kdeplot(X_train_tranformed['Age'])
plt.title('Age After Log')

plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
sns.kdeplot(X_train['Fare'])
plt.title('Fare Before Log')

plt.subplot(1, 2, 2)
sns.kdeplot(X_train_tranformed['Fare'])
plt.title('Fare After Log')

plt.show()
